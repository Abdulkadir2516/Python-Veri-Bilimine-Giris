# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
x1 = np.array(range(0,5,1))

plt.plot(x1)
plt.show()

# %%
"""Style	Or
'solid' (default)	'-'	
'dotted'	':'	
'dashed'	'--'	
'dashdot'	'-.'	
'None'	'' or ' '
"""

plt.plot(x1, "o-r")

plt.plot(x1+1, linestyle="solid")
plt.plot(x1+2, ls="dotted")
plt.plot(x1+3, ls="dashed")
plt.plot(x1+4, ls="dashdot")

# %%
plt.plot(x1, color="red")
plt.plot(x1+2, c="blue")
plt.plot(x1+4, c="#000000") # hex

# %%
plt.plot(x1, linewidth=20)

# %%
plt.plot(x1)

font1 = {'family':'algerian','color':'blue','size':20}
font2 = {'family':'times new roman','color':'darkred','size':15}
font3 = {'family':'arial','color':'red','size':15}

plt.title("P5 Matplotlib-2", fontdict = font1 , loc="left")
plt.xlabel("x ekseni", fontdict = font2)
plt.ylabel("y ekseni", fontdict = font3)
# Out:
# Text(0, 0.5, 'y ekseni')

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'algerian','color':'red','size':20}
font2 = {'family':'serif','color':'blue','size':15}
font3 = {'family':'sans','color':'cyan','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font3)

plt.plot(x, y)
plt.show()
